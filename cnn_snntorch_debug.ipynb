# %%
import snntorch as snn
import torch
from snntorch.export_nir import export_to_nir
from snntorch.import_nir import import_from_nir

import numpy as np
import nir

# %%
nir_file_path = "nir_examples/cnn_sinabs.nir"
testbench_path = "nir_examples/cnn_teste.npz"

nir_graph = nir.read(nir_file_path)
nodes = nir_graph.nodes
edges = nir_graph.edges

net = import_from_nir(nir_graph)
# Out:
# replace rnn subgraph with nirgraph

# %%
print(net)
# Out:
# GraphExecutor(
#   (0): Conv2d(2, 16, kernel_size=(5, 5), stride=(2, 2), padding=(1, 1))
#   (1): Leaky()
#   (10): Leaky()
#   (11): Linear(in_features=256, out_features=10, bias=True)
#   (12): Leaky()
#   (2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): Leaky()
#   (4): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#   (5): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): Leaky()
#   (7): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#   (8): Flatten(start_dim=0, end_dim=-1)
#   (9): Linear(in_features=128, out_features=256, bias=True)
#   (input): Identity()
#   (output): Identity()
# )

# %%
print(nodes['input'])
# Out:
# Input(input_type={'input': array([ 2, 34, 34])})

# %%
print(net)
# Out:
# GraphExecutor(
#   (0): Conv2d(2, 16, kernel_size=(5, 5), stride=(2, 2), padding=(1, 1))
#   (1): Leaky()
#   (10): Leaky()
#   (11): Linear(in_features=256, out_features=10, bias=True)
#   (12): Leaky()
#   (2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): Leaky()
#   (4): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#   (5): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): Leaky()
#   (7): AvgPool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#   (8): Flatten(start_dim=0, end_dim=-1)
#   (9): Linear(in_features=128, out_features=256, bias=True)
#   (input): Identity()
#   (output): Identity()
# )

# %%
dataset = np.load(testbench_path)

data = dataset["data"][0][0]
labels = dataset["labels"]

# %%
print(data.shape)
# Out:
# (2, 34, 34)

# %%
print(net.forward(data))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 print(net.forward(data))
#
# File ~/miniconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/nirtorch/from_nir.py:148, in GraphExecutor.forward(self, data, old_state)
#     146 if node.elem is None:
#     147     continue
# --> 148 out, new_state = self._apply_module(
#     149     node,
#     150     input_nodes,
#     151     new_state=new_state,
#     152     old_state=old_state,
#     153     data=data if first_node else None,
#     154 )
#     155 new_state.cache[node.name] = out
#     156 first_node = False
#
# File ~/miniconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/nirtorch/from_nir.py:121, in GraphExecutor._apply_module(self, node, input_nodes, new_state, old_state, data)
#     118 elif len(summed_inputs) > 1:
#     119     inputs.insert(0, torch.stack(summed_inputs).sum(0))
# ...
