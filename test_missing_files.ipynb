# %%
from NeuroHls import *

# %%
neuro_hls = NeuroHls("test_missing_files")

# %%
neuro_hls.run_csim()
# Out:
# Creating Vitis Project...
#
# ------------------------------
# Testbench Status
# ------------------------------
#
#  - Test dataset: MISSING
#  - Test targets: MISSING
#  - Testbench file: OK
#
#    Ready? NO
#
# *** Project creation aborted.
#
# *** Unable to run C-Simulation.
