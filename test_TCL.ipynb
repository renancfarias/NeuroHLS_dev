# %%
from NeuroHls import *

# %%
neuro_hls = NeuroHls("tcl_test", should_recreate_files=False)

# %%
neuro_hls.define_project_and_solution(project_name="proj_teste_5_jan", solution_name="solution_1")

# %%
neuro_hls.create_project()
# Out:
# ****** Vitis HLS - High-Level Synthesis from C, C++ and OpenCL v2024.2 (64-bit)
#   **** SW Build 5238294 on Nov  8 2024
#   **** IP Build 5239520 on Sun Nov 10 16:12:51 MST 2024
#   **** SharedData Build 5239561 on Fri Nov 08 14:39:27 MST 2024
#   **** Start of session at: Mon Jan  5 17:28:12 2026
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2024 Advanced Micro Devices, Inc. All Rights Reserved.
#
# source /tools/Xilinx/Vitis/2024.2/scripts/vitis_hls/hls.tcl -notrace
# INFO: [HLS 200-10] For user 'user3' on host 'user3-Z690-PG-Riptide' (Linux_x86_64 version 6.11.0-28-generic) on Mon Jan 05 17:28:13 -03 2026
# INFO: [HLS 200-10] On os Ubuntu 24.04.3 LTS
# INFO: [HLS 200-10] In directory '/home/user3/Documentos/Fernando/NeuroHLS_dev_nir_to_cpp/NeuroHLS_dev/tcl_test'
# WARNING: [HLS 200-2053] The vitis_hls executable is deprecated. Consider using vitis-run --mode hls --tcl
# Sourcing Tcl script '0_create_project.tcl'
# ...

# %%
neuro_hls.run_csim()
# Out:
# ****** Vitis HLS - High-Level Synthesis from C, C++ and OpenCL v2024.2 (64-bit)
#   **** SW Build 5238294 on Nov  8 2024
#   **** IP Build 5239520 on Sun Nov 10 16:12:51 MST 2024
#   **** SharedData Build 5239561 on Fri Nov 08 14:39:27 MST 2024
#   **** Start of session at: Mon Jan  5 17:28:14 2026
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2024 Advanced Micro Devices, Inc. All Rights Reserved.
#
# source /tools/Xilinx/Vitis/2024.2/scripts/vitis_hls/hls.tcl -notrace
# INFO: [HLS 200-10] For user 'user3' on host 'user3-Z690-PG-Riptide' (Linux_x86_64 version 6.11.0-28-generic) on Mon Jan 05 17:28:14 -03 2026
# INFO: [HLS 200-10] On os Ubuntu 24.04.3 LTS
# INFO: [HLS 200-10] In directory '/home/user3/Documentos/Fernando/NeuroHLS_dev_nir_to_cpp/NeuroHLS_dev/tcl_test'
# WARNING: [HLS 200-2053] The vitis_hls executable is deprecated. Consider using vitis-run --mode hls --tcl
# Sourcing Tcl script '1_csim.tcl'
# ...

# %%
neuro_hls.run_synth(clk_period=15)
# Out:
# ****** Vitis HLS - High-Level Synthesis from C, C++ and OpenCL v2024.2 (64-bit)
#   **** SW Build 5238294 on Nov  8 2024
#   **** IP Build 5239520 on Sun Nov 10 16:12:51 MST 2024
#   **** SharedData Build 5239561 on Fri Nov 08 14:39:27 MST 2024
#   **** Start of session at: Mon Jan  5 17:28:57 2026
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2024 Advanced Micro Devices, Inc. All Rights Reserved.
#
# source /tools/Xilinx/Vitis/2024.2/scripts/vitis_hls/hls.tcl -notrace
# INFO: [HLS 200-10] For user 'user3' on host 'user3-Z690-PG-Riptide' (Linux_x86_64 version 6.11.0-28-generic) on Mon Jan 05 17:28:58 -03 2026
# INFO: [HLS 200-10] On os Ubuntu 24.04.3 LTS
# INFO: [HLS 200-10] In directory '/home/user3/Documentos/Fernando/NeuroHLS_dev_nir_to_cpp/NeuroHLS_dev/tcl_test'
# WARNING: [HLS 200-2053] The vitis_hls executable is deprecated. Consider using vitis-run --mode hls --tcl
# Sourcing Tcl script '2_synth.tcl'
# ...
